# %% [markdown]
# ## **Basic processing of news contents**

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Import the newscontent of scraped news articles from 1 Oct to 5 OCt

df=pd.read_csv('newscontent.csv',header=None)

df.columns=['content']

# %%
df.head(5)
df
# Out:
#                                                content
# 0    Open source browser-based cryptocurrency walle...
# 1    Bitcoin is close to bottoming, and once it reb...
# 2    Very very quiet week this. Not much new ransom...
# 3    A recent survey by Fundstrat Global Advisors h...
# 4    Is this the start of a new phase for Bitcoin o...
# 5    On October 5, 2018, an article published by Bl...
# 6    Track the price of your favourite cryptocurren...
# 7    An exchange-traded bitcoin fund (ETF) would si...
# 8    "It is just not credible that the United State...
# 9    BitGo, a major Palo Alto-based cryptocurrency ...
# 10   Earlier this year, the city of Atlanta was str...
# 11                                                 NaN
# 12   The Securities and Exchange Commission (SEC) h...
# 13   Scammers are taking advantage of Fortnite 's p...
# 14                                                 NaN
# 15   The story of this week: Crude Oil- Brent makes...
# 16   &lt;iframe style="border: none" src="//html5-p...
# 17   Famous rapper Soulja Boy might just be a bitco...
# 18   BLACKSBURG Block.one has quietly moved into it...
# 19   Herstatt risk or settlement risk is the risk t...
# 20   Recent rumors claim that a BlackBerry licensee...
# 21   NEW YORK (Reuters) - Speculators’ net long bet...
# 22   October 5, 2018: Markets opened mixed Friday e...
# 23   After finding much success in their unique “Bu...
# 24   A couple of days ago, we told you that Optiemu...
# 25   Tracklist: 1. No Hook (True Story) 2. Run up a...
# 26   Square ( NYSE:SQ ) management told investors a...
# 27   The market for cryptocurrency may have slowed ...
# 28   Credit Card Giant Chase Jumps Into Tours and A...
# 29   A new survey conducted by Fundstrat Global Adv...
# ..                                                 ...
# 951  Google Play Boots 3 Pretend DeepOnion Wallet A...
# 952  Andreessen Horowitz, the prominent Silicon Val...
# 953  Here are the key things you need to know befor...
# 954  The new six-month release cadence of the JDK m...
# 955  Share to facebook Share to twitter Share to li...
# 956  Michael J. Casey is the chairman of CoinDesk's...
# 957  The prices of digital currencies have collapse...
# 958  As Extra Builders Be part ofTurns out No perso...
# 959  I have been Promoting On LocalDeepOnions For A...
# 960  $10,467,596,650.78 For DeepOnion (Investopedia...
# 961  Apart from ThatOther than That I can verify th...
# 962  The DeepOnion Core DNS Seed CoverageThe Design...
# 963  This story was delivered to Business Insider I...
# 964  $5. Blockchain Can Do Even BetterPurchase A De...
# 965  Last week, our server has been attacked by a h...
# 966  Is Narrative Pushed By DeepOnion, Cryptocurren...
# 967  If You need to use A DeepOnion Wallet'Darkish ...
# 968  $5. Blockchain Can Do Even BetterThe Disruptiv...
# 969  The Blockchain Weekly Front Page is a CXO leve...
# 970  Australian Dollar Talking Points: Australian i...
# 971  Ransomware has infected computers used by the ...
# 972  A 'stablecoin' is a cryptocurrency that's pric...
# 973  Cyber security sleuths are scrambling to prote...
# 974  We live in a logical world that has rested its...
# 975  Note: This is part 2 in a multi-part interview...
# 976  California Gov. Jerry Brown has signed into la...
# 977  Port of San Diego CEO Randa Coniglio announced...
# 978  Year-to-year, week-to-week, even day-to-day te...
# 979  OCT Corp., headquartered in Yokohama, Japan, Y...
# 980  OCT Corp., headquartered in Yokohama, Japan, Y...
#
# [981 rows x 1 columns]

# %%
#drop news with no contents

df=df.dropna()

# %%
#display the content text length of every piece of news

df['text length'] = df['content'].apply(len)
df
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                content  text length
# 0    Open source browser-based cryptocurrency walle...          274
# 1    Bitcoin is close to bottoming, and once it reb...          274
# 2    Very very quiet week this. Not much new ransom...          274
# 3    A recent survey by Fundstrat Global Advisors h...          274
# 4    Is this the start of a new phase for Bitcoin o...          274
# 5    On October 5, 2018, an article published by Bl...          274
# 6    Track the price of your favourite cryptocurren...          273
# 7    An exchange-traded bitcoin fund (ETF) would si...          274
# 8    "It is just not credible that the United State...          275
# 9    BitGo, a major Palo Alto-based cryptocurrency ...          274
# 10   Earlier this year, the city of Atlanta was str...          274
# 12   The Securities and Exchange Commission (SEC) h...          274
# 13   Scammers are taking advantage of Fortnite 's p...          274
# 15   The story of this week: Crude Oil- Brent makes...          274
# 16   &lt;iframe style="border: none" src="//html5-p...          274
# 17   Famous rapper Soulja Boy might just be a bitco...          274
# 18   BLACKSBURG Block.one has quietly moved into it...          274
# 19   Herstatt risk or settlement risk is the risk t...          274
# 20   Recent rumors claim that a BlackBerry licensee...          274
# 21   NEW YORK (Reuters) - Speculators’ net long bet...          274
# 22   October 5, 2018: Markets opened mixed Friday e...          274
# 23   After finding much success in their unique “Bu...          274
# 24   A couple of days ago, we told you that Optiemu...          274
# 25   Tracklist: 1. No Hook (True Story) 2. Run up a...          273
# 26   Square ( NYSE:SQ ) management told investors a...          274
# 27   The market for cryptocurrency may have slowed ...          274
# 28   Credit Card Giant Chase Jumps Into Tours and A...          275
# 29   A new survey conducted by Fundstrat Global Adv...          274
# 30   Satoshi Nakamoto was most likely not a Russian...          274
# 31   Yale Universitys latest alternative investment...          274
# ..                                                 ...          ...
# 951  Google Play Boots 3 Pretend DeepOnion Wallet A...          273
# 952  Andreessen Horowitz, the prominent Silicon Val...          274
# 953  Here are the key things you need to know befor...          274
# 954  The new six-month release cadence of the JDK m...          274
# 955  Share to facebook Share to twitter Share to li...          275
# 956  Michael J. Casey is the chairman of CoinDesk's...          274
# 957  The prices of digital currencies have collapse...          274
# 958  As Extra Builders Be part ofTurns out No perso...          273
# 959  I have been Promoting On LocalDeepOnions For A...          273
# 960  $10,467,596,650.78 For DeepOnion (Investopedia...          273
# 961  Apart from ThatOther than That I can verify th...          273
# 962  The DeepOnion Core DNS Seed CoverageThe Design...          273
# 963  This story was delivered to Business Insider I...          274
# 964  $5. Blockchain Can Do Even BetterPurchase A De...          273
# 965  Last week, our server has been attacked by a h...          273
# 966  Is Narrative Pushed By DeepOnion, Cryptocurren...          273
# 967  If You need to use A DeepOnion Wallet'Darkish ...          273
# 968  $5. Blockchain Can Do Even BetterThe Disruptiv...          273
# 969  The Blockchain Weekly Front Page is a CXO leve...          274
# 970  Australian Dollar Talking Points: Australian i...          274
# 971  Ransomware has infected computers used by the ...          274
# 972  A 'stablecoin' is a cryptocurrency that's pric...          274
# 973  Cyber security sleuths are scrambling to prote...          274
# 974  We live in a logical world that has rested its...          274
# 975  Note: This is part 2 in a multi-part interview...          275
# 976  California Gov. Jerry Brown has signed into la...          274
# 977  Port of San Diego CEO Randa Coniglio announced...          274
# 978  Year-to-year, week-to-week, even day-to-day te...          274
# 979  OCT Corp., headquartered in Yokohama, Japan, Y...          274
# 980  OCT Corp., headquartered in Yokohama, Japan, Y...          274
#
# [951 rows x 2 columns]

# %% [markdown]
# ## **Remove punctuation and stopwords**

# %%
import string

import nltk
from nltk.corpus import stopwords

#Split the words in contents

def text_process(text):
 
    nopunc = [char for char in text]
    nopunc = ''.join(nopunc)
    
    return [word for word in nopunc.split()]

# %%
content_text2=text_process(df['content'])

# %%
tokens=content_text2

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print(words[:100])
# Out:
# ['open', 'source', 'browserbased', 'cryptocurrency', 'wallet', 'telescope', 'officially', 'announced', 'acquisition', 'bitmain', 'technologies', 'inc', 'largest', 'crypto', 'mining', 'rig', 'manufacturer', 'also', 'runs', 'one', 'extensive', 'cryptocurrency', 'mining', 'charsbitcoin', 'close', 'bottoming', 'rebounds', 'weeks', 'developments', 'fuel', 'climb', 'said', 'spencer', 'bogart', 'cryptocurrency', 'blockchain', 'venture', 'firm', 'blockchain', 'capital', 'percent', 'highs', 'think', 'bitcoin', 'charsvery', 'quiet', 'week', 'much', 'new', 'ransomware', 'report', 'released', 'well', 'known', 'variants', 'like', 'matrix', 'dharma', 'ransomware', 'infections', 'biggest', 'news', 'shut', 'numerous', 'restaurants', 'part', 'recipe', 'unlimited', 'charsa', 'recent', 'survey', 'fundstrat', 'global', 'advisors', 'revealed', 'bullish', 'sentiments', 'among', 'institutional', 'investors', 'regards', 'prospects', 'cryptocurrency', 'performance', 'economic', 'recession', 'investors', 'say', 'recession', 'boost', 'cryptocurrency', 'prices', 'charsis', 'start', 'new', 'phase', 'bitcoin', 'beginning', 'end', 'biggest']

# %% [markdown]
# ## **Find the most frequent 100 words**

# %%
import nltk
freq_clean = nltk.FreqDist(words)
freq=freq_clean.most_common(100)

# %% [markdown]
# ## **Write 100 frequent words into a file called corpora**

# %%
freq_corpora=pd.DataFrame(freq,columns=['Words','Frequency'])
freq_corpora.to_csv('corpora.csv',index_label = False,index=False)
freq_corpora
# Out:
#                Words  Frequency
# 0            bitcoin        320
# 1     cryptocurrency        227
# 2                new        143
# 3         blockchain        135
# 4                 us        130
# 5             market        114
# 6           charsthe        101
# 7             crypto         88
# 8           exchange         84
# 9            digital         84
# 10             price         82
# 11        technology         82
# 12             world         77
# 13              data         77
# 14           trading         74
# 15  cryptocurrencies         72
# 16               one         71
# 17               oct         58
# 18              year         56
# 19            around         56
# 20             today         56
# 21         financial         55
# 22         investors         54
# 23             first         54
# 24           company         53
# 25          security         53
# 26              week         49
# 27              time         49
# 28              said         48
# 29        prnewswire         48
# ..               ...        ...
# 70             chart         31
# 71             since         30
# 72           billion         30
# 73              like         29
# 74               get         29
# 75             share         29
# 76             trend         29
# 77               ccn         29
# 78          thursday         29
# 79               key         29
# 80            wallet         28
# 81               use         28
# 82        resistance         28
# 83           percent         27
# 84              part         27
# 85              back         27
# 86              even         27
# 87           network         27
# 88              cash         27
# 89            monday         27
# 90            prices         26
# 91              bank         26
# 92              york         26
# 93            online         26
# 94              make         26
# 95              coin         26
# 96      intelligence         26
# 97               ceo         26
# 98           largest         25
# 99              also         25
#
# [100 rows x 2 columns]
