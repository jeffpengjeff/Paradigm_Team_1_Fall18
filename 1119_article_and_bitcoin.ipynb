# %%
# Import Libraries and Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import datetime
import nltk
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
eng_stopwords = nltk.corpus.stopwords.words('english')
articles=pd.read_csv("New_marked_news.csv").drop('Unnamed: 0', axis = 1)
articles.head()
# Out:
#            author                                           contents  \
# 0  Bitcoinist.net  real time prices vires numeris bitcoin ethereu...
# 1    Michelle Fox  var postloadfunctions var foresee enabled var ...
# 2   Scott Scanlon  at core cryptocurrency networks miners people ...
# 3  Bruce Kleinman  demons digital gold part if already done pleas...
# 4    Jason Murphy  email password remember me feb while systems u...
#
#                                          description        publisher  \
# 0  With Israel’s Finance Ministry and the Bank of...   Bitcoinist.com
# 1  Bitcoin may still drop to $7,500, but it will ...             CNBC
# 2  At the core of most cryptocurrency networks ar...  Youbrandinc.com
# 3                     Demons in Digital Gold, Part 5   Hackernoon.com
# 4  While the systems underpinning bitcoin are tru...    Crikey.com.au
#
#                                           source_url  \
# 0  http://bitcoinist.com/kosher-crypto-bitcoen-se...
# 1  https://www.cnbc.com/2018/02/01/bitcoin-near-b...
# 2  https://www.youbrandinc.com/crytocurrency/brai...
# 3  https://hackernoon.com/remediation-wherefore-a...
# 4  https://www.crikey.com.au/2018/02/02/cryptotra...
#
#                                                title        date      time  \
# 0  Kosher Crypto BitCoen Is Setting a Course for ...  2018-02-02  00:00:08
# 1  Bitcoin near bottom, will rally to $20,000 thi...  2018-02-02  00:02:00
# 2  Brain Genius Submerges His Bitcoin Mining Rig ...  2018-02-02  00:03:08
# 3                   Remediation, wherefore art thou?  2018-02-02  00:18:34
# 4  Cryptotragedy: what if bitcoin’s greatest stre...  2018-02-02  00:25:09
#
#           Open         High ...   Volume_(BTC)  Volume_(Currency)  \
# 0  8547.864403  8562.224306 ...      35.615632      300510.207066
# 1  8547.864403  8562.224306 ...      35.615632      300510.207066
# 2  8547.864403  8562.224306 ...      35.615632      300510.207066
# 3  8547.864403  8562.224306 ...      35.615632      300510.207066
# 4  8547.864403  8562.224306 ...      35.615632      300510.207066
#
#    Weighted_Price       Average     Volatility           SD  publisherLabel  \
# 0     8547.594042  12603.493539  433909.334353  2087.647258              96
# 1     8547.594042  12603.493539  433909.334353  2087.647258             146
# 2     8547.594042  12603.493539  433909.334353  2087.647258            1181
# 3     8547.594042  12603.493539  433909.334353  2087.647258             452
# 4     8547.594042  12603.493539  433909.334353  2087.647258             220
#
#        Date_x      Date_y Mark
# 0  2018-02-02  2018-02-02  1.0
# 1  2018-02-02  2018-02-02  1.0
# 2  2018-02-02  2018-02-02  1.0
# 3  2018-02-02  2018-02-02  1.0
# 4  2018-02-02  2018-02-02  1.0
#
# [5 rows x 22 columns]

# %%
# df_marker_1=pd.read_csv("markerPosi.csv")
# df_marker_2=pd.read_csv("markerNega.csv")
# frames=[df_marker_1,df_marker_2]
# df_marker= pd.concat(frames, ignore_index=True)
# df_marker.tail()

# %%
#df['marker']=np.zeros(len(df))
#for i in range(len(df)-1):
    #if df['date'][i] in df_marker['Date']:
#         df['marker'][i]=1
#     else:
#         df['marker'][i]=0
# df

# %% [markdown]
# __Standardize timestamps__

# %%
#temp = pd.DatetimeIndex(articles['timeStamp']) # Gather all datetime objects
#articles['date'] = temp.date                   # Pull out the date from the datetime objects and assign to Date column
#articles['time'] = temp.time                   # Pull out the time from the datetime objects and assign to Time column
print(len(articles))
articles.tail(3)
# Out:
# 7101
#                  author                                           contents  \
# 7098         Kellie Ell  var postloadfunctions var foresee enabled var ...
# 7099               TWiT  mar st facebook cambridge analytica scandal go...
# 7100  Stephen Shankland  cnet tambi n est disponible en espa ol don sho...
#
#                                             description publisher  \
# 7098  Blockchain technology has the potential to tra...      CNBC
# 7099  Facebook and the Cambridge Analytica scandal. ...   Twit.tv
# 7100  The hotly hyped technology, which has the pote...  Cnet.com
#
#                                              source_url  \
# 7098  https://www.cnbc.com/2018/03/21/facebooks-pain...
# 7099  https://twit.tv/shows/this-week-in-google/epis...
# 7100  https://www.cnet.com/news/google-could-offer-b...
#
#                                                   title        date      time  \
# 7098  Facebook's pain could be blockchain's gain: An...  2018-03-21  23:35:00
# 7099  This Week in Google 449: Grackles, Nuthatches,...  2018-03-21  23:56:07
# 7100  Google reportedly planning blockchain-based se...  2018-03-21  23:59:33
#
#              Open         High ...   Volume_(BTC)  Volume_(Currency)  \
# 7098  8980.556882  8983.223576 ...      10.814751       96858.759087
# 7099  8980.556882  8983.223576 ...      10.814751       96858.759087
# 7100  8980.556882  8983.223576 ...      10.814751       96858.759087
#
#       Weighted_Price      Average     Volatility           SD  publisherLabel  \
# 7098     8980.452085  9786.788157  235829.110947  1134.633339             146
# 7099     8980.452085  9786.788157  235829.110947  1134.633339            1101
# 7100     8980.452085  9786.788157  235829.110947  1134.633339             189
#
#           Date_x      Date_y Mark
# 7098  2018-03-21  2018-03-21  1.0
# 7099  2018-03-21  2018-03-21  1.0
# 7100  2018-03-21  2018-03-21  1.0
#
# [3 rows x 22 columns]

# %%
articles.contents[10]
# Out:
# 'after several short lived drops looks like price bitcoin finally yielded pressure the largest cryptocurrency market cap currently trading percent last hours according coinmarketcap the trigger price drop likely news india finance minister arun jaitley expressed largely negative view towards cryptocurrencies budget speech see also a little known token may fueling bitcoin rise critics say scam the government consider cryptocurrencies legal tender coin take measures eliminate use crypto assets financing illegitimate activities part payment system jaitley said according fortune read read mashable com thumbnail courtesy mashable com is chief doer you brand inc also master curator wordpress content curation platform curation suite username email address password remember me'

# %% [markdown]
# __Preprocess text for NLP formulations__

# %%
articles.head()
# Out:
#            author                                           contents  \
# 0  Bitcoinist.net  real time prices vires numeris bitcoin ethereu...
# 1    Michelle Fox  var postloadfunctions var foresee enabled var ...
# 2   Scott Scanlon  at core cryptocurrency networks miners people ...
# 3  Bruce Kleinman  demons digital gold part if already done pleas...
# 4    Jason Murphy  email password remember me feb while systems u...
#
#                                          description        publisher  \
# 0  With Israel’s Finance Ministry and the Bank of...   Bitcoinist.com
# 1  Bitcoin may still drop to $7,500, but it will ...             CNBC
# 2  At the core of most cryptocurrency networks ar...  Youbrandinc.com
# 3                     Demons in Digital Gold, Part 5   Hackernoon.com
# 4  While the systems underpinning bitcoin are tru...    Crikey.com.au
#
#                                           source_url  \
# 0  http://bitcoinist.com/kosher-crypto-bitcoen-se...
# 1  https://www.cnbc.com/2018/02/01/bitcoin-near-b...
# 2  https://www.youbrandinc.com/crytocurrency/brai...
# 3  https://hackernoon.com/remediation-wherefore-a...
# 4  https://www.crikey.com.au/2018/02/02/cryptotra...
#
#                                                title        date      time  \
# 0  Kosher Crypto BitCoen Is Setting a Course for ...  2018-02-02  00:00:08
# 1  Bitcoin near bottom, will rally to $20,000 thi...  2018-02-02  00:02:00
# 2  Brain Genius Submerges His Bitcoin Mining Rig ...  2018-02-02  00:03:08
# 3                   Remediation, wherefore art thou?  2018-02-02  00:18:34
# 4  Cryptotragedy: what if bitcoin’s greatest stre...  2018-02-02  00:25:09
#
#           Open         High ...   Volume_(BTC)  Volume_(Currency)  \
# 0  8547.864403  8562.224306 ...      35.615632      300510.207066
# 1  8547.864403  8562.224306 ...      35.615632      300510.207066
# 2  8547.864403  8562.224306 ...      35.615632      300510.207066
# 3  8547.864403  8562.224306 ...      35.615632      300510.207066
# 4  8547.864403  8562.224306 ...      35.615632      300510.207066
#
#    Weighted_Price       Average     Volatility           SD  publisherLabel  \
# 0     8547.594042  12603.493539  433909.334353  2087.647258              96
# 1     8547.594042  12603.493539  433909.334353  2087.647258             146
# 2     8547.594042  12603.493539  433909.334353  2087.647258            1181
# 3     8547.594042  12603.493539  433909.334353  2087.647258             452
# 4     8547.594042  12603.493539  433909.334353  2087.647258             220
#
#        Date_x      Date_y Mark
# 0  2018-02-02  2018-02-02  1.0
# 1  2018-02-02  2018-02-02  1.0
# 2  2018-02-02  2018-02-02  1.0
# 3  2018-02-02  2018-02-02  1.0
# 4  2018-02-02  2018-02-02  1.0
#
# [5 rows x 22 columns]

# %%
#Clean the articles - Remove stopwords, remove punctuation, all lowercase
import re
for i in articles.index:
    text = articles.loc[i, 'contents']
    if pd.isnull(text):
        pass
    else:
        text = re.sub(r"[^a-zA-Z]", " ", text)
        text = [word for word in text.split() if not word in eng_stopwords]
        text = (' '.join(text))
        text = text.lower()
        articles.loc[i, 'contents'] = text

# %% [markdown]
# __Combine cleaned articles with "Markers" from Time Series event detection__

# %%
df=articles
df.to_csv("1119_article_data_and_price_labeled_publisher.csv")

# %% [markdown]
# ___
